# %%
# -*- coding: utf-8 -*-
# 파일명: train_models_v2.py (새로운 데이터셋으로 모델 재학습)
# 실행 환경: 64비트 Python (myenv)
# 필요 라이브러리: tensorflow, pandas, numpy, scikit-learn

import pandas as pd
import numpy as np
import os
import time
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam # Adam 임포트 명시
import warnings
import gc
import traceback
warnings.filterwarnings('ignore')

# --- 1. 설정값 정의 ---
# ★★★ 경로 수정: 새로 가공된 데이터 및 새 모델 저장 경로 ★★★
PROCESSED_DATA_PATH = '/content/drive/MyDrive/processed_stock_data_full_v2/processed_parquet'
NEW_MODEL_SAVE_PATH = '/content/drive/MyDrive/lstm_models_per_stock_v2'

# 모델 하이퍼파라미터 (이전과 동일하게 유지하거나 필요시 조정)
TIME_STEPS = 20
TRAIN_RATIO = 0.7
VALID_RATIO = 0.15
# TEST_RATIO = 1 - TRAIN_RATIO - VALID_RATIO
EPOCHS = 50 # 최대 에포크 (EarlyStopping 사용)
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# ★★★ 사용할 피처 컬럼 목록 (데이터 처리 스크립트와 동일하게) ★★★
# process_and_save_data_with_scalers.py 에서 최종 Parquet에 저장된 컬럼 중 모델 입력으로 사용할 것들
# _norm 접미사가 붙은 정규화된 피처와, 정규화 안 된 피처(is_month_end) 등
FEATURE_COLUMNS_FOR_MODEL = [
    'open_norm', 'high_norm', 'low_norm', 'close_norm', 'volume_norm', 'amount_norm',
    'SMA_5_norm', 'SMA_20_norm', 'SMA_60_norm', 'SMA_120_norm', 'RSI_14_norm',
    'MACD_12_26_9_norm', 'MACDs_12_26_9_norm', 'MACDh_12_26_9_norm',
    'BBL_20_2.0_norm', 'BBM_20_2.0_norm', 'BBU_20_2.0_norm', 'BBB_20_2.0_norm', 'BBP_20_2.0_norm',
    'ATRr_14_norm', 'OBV_norm', 'STOCHk_14_3_3_norm', 'STOCHd_14_3_3_norm',
    'PBR_norm', 'PER_norm', 'USD_KRW_norm', # 이 값들은 Parquet 파일에 _norm으로 저장됨
    'is_month_end' # 이 값은 원본 그대로 Parquet 파일에 저장됨
]
TARGET_COLUMN_FOR_MODEL = 'close_norm' # 예측 대상 컬럼 (정규화된 종가)

NUM_FEATURES_FOR_MODEL = len(FEATURE_COLUMNS_FOR_MODEL)

LIMIT_STOCKS_TO_TRAIN = None # ★★★ None이면 전체 학습, 테스트 시 5 등으로 설정 ★★★
# ---------------------------------------------------------

# --- 2. 모델 저장 경로 생성 ---
os.makedirs(NEW_MODEL_SAVE_PATH, exist_ok=True)
print(f"가공된 데이터 경로: {PROCESSED_DATA_PATH}")
print(f"새 모델 저장 경로: {NEW_MODEL_SAVE_PATH}")

# --- 3. 학습할 데이터 파일 목록 가져오기 ---
try:
    parquet_files = [f for f in os.listdir(PROCESSED_DATA_PATH) if f.endswith('.parquet')]
    if not parquet_files:
        raise FileNotFoundError(f"Parquet 파일이 '{PROCESSED_DATA_PATH}' 경로에 없습니다.")
    parquet_files.sort() # 일관된 순서로 처리
    print(f"총 {len(parquet_files)}개의 Parquet 파일 확인.")
    if LIMIT_STOCKS_TO_TRAIN is not None and LIMIT_STOCKS_TO_TRAIN > 0:
        parquet_files = parquet_files[:LIMIT_STOCKS_TO_TRAIN]
        print(f"★★ 테스트를 위해 {LIMIT_STOCKS_TO_TRAIN}개 종목만 학습합니다. ★★")
except FileNotFoundError as e:
    print(f"오류: {e}. 데이터 경로를 확인하세요.")
    exit()
except Exception as e:
    print(f"파일 목록 로딩 중 오류 발생: {e}")
    exit()

# --- 4. 시퀀스 생성 함수 ---
def create_sequences(data, target, time_steps=TIME_STEPS): # time_steps 전역변수 사용
    Xs, ys = [], []
    # feature_data는 이미 선택된 컬럼들로 구성된 NumPy 배열이라고 가정
    for i in range(len(data) - time_steps):
        Xs.append(data[i:(i + time_steps)])
        ys.append(target[i + time_steps]) # time_steps 이후의 target 값
    return np.array(Xs), np.array(ys)

# --- 5. LSTM 모델 정의 함수 ---
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=128, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dense(units=1)) # 출력층
    return model

# --- 6. 전체 종목 모델 학습 루프 ---
print(f"\n--- {len(parquet_files)}개 종목 모델 재학습 시작 ---")
total_train_start_time = time.time()
models_trained_count = 0
models_failed_count = 0

for i, file_name in enumerate(parquet_files):
    ticker = file_name.replace('.parquet', '')
    data_file_path = os.path.join(PROCESSED_DATA_PATH, file_name)
    model_save_file_path = os.path.join(NEW_MODEL_SAVE_PATH, f"{ticker}.keras")

    print(f"\n[{i+1}/{len(parquet_files)}] Ticker: {ticker} 학습 시작...")
    ticker_train_start_time = time.time()

    try:
        # 6.1 데이터 로드
        df_loaded = pd.read_parquet(data_file_path)

        # 사용할 피처 및 타겟 컬럼 존재 확인
        missing_cols = [col for col in FEATURE_COLUMNS_FOR_MODEL if col not in df_loaded.columns]
        if missing_cols:
            print(f"  >> 오류: 필요한 피처 컬럼 누락: {missing_cols}. 건너<0xEB><0x8A>니다.")
            models_failed_count += 1
            continue
        if TARGET_COLUMN_FOR_MODEL not in df_loaded.columns:
            print(f"  >> 오류: 타겟 컬럼 '{TARGET_COLUMN_FOR_MODEL}' 없음. 건너<0xEB><0x8A>니다.")
            models_failed_count += 1
            continue

        # 피처 및 타겟 데이터 추출
        feature_data = df_loaded[FEATURE_COLUMNS_FOR_MODEL].values.astype(np.float32)
        target_data = df_loaded[TARGET_COLUMN_FOR_MODEL].values.astype(np.float32)

        # NaN 값 확인 (이론적으로는 이전 단계에서 dropna 했으므로 없어야 함)
        if np.isnan(feature_data).any() or np.isnan(target_data).any():
             print(f"  >> 경고: 로드된 데이터에 NaN 존재. nan_to_num 처리 시도.")
             feature_data = np.nan_to_num(feature_data, nan=0.0) # 임시로 0으로 대체
             target_data = np.nan_to_num(target_data, nan=0.0)

        # 6.2 시퀀스 생성
        X, y = create_sequences(feature_data, target_data) # TIME_STEPS는 전역변수 사용

        if len(X) < (TIME_STEPS * 2): # 분할에 충분한 시퀀스 길이 확인 (최소 Train/Valid)
             print(f"  >> 경고: 시퀀스 생성 후 데이터 길이 부족 ({len(X)}). 건너<0xEB><0x8A>니다.")
             models_failed_count += 1
             continue

        # 6.3 데이터 분할 (Train/Validation/Test) - 시계열 특성 유지
        n_total = len(X)
        n_train = int(n_total * TRAIN_RATIO)
        n_valid = int(n_total * VALID_RATIO)
        # n_test = n_total - n_train - n_valid # 테스트는 학습 후 별도 평가

        X_train, y_train = X[:n_train], y[:n_train]
        X_valid, y_valid = X[n_train : n_train + n_valid], y[n_train : n_train + n_valid]
        # X_test, y_test = X[n_train + n_valid:], y[n_train + n_valid:] # 테스트셋은 저장된 모델로 나중에 평가

        if len(X_train) == 0 or len(X_valid) == 0 or X_train.shape[1] != TIME_STEPS or X_train.shape[2] != NUM_FEATURES_FOR_MODEL:
             print(f"  >> 경고: 학습 또는 검증 데이터 형태 오류 또는 부족. 건너<0xEB><0x8A>니다.")
             print(f"     Train shape: {X_train.shape if len(X_train)>0 else 'Empty'}, Valid shape: {X_valid.shape if len(X_valid)>0 else 'Empty'}")
             print(f"     Expected TIME_STEPS: {TIME_STEPS}, Expected NUM_FEATURES: {NUM_FEATURES_FOR_MODEL}")
             models_failed_count += 1
             continue

        print(f"  >> 데이터 분할: Train={len(X_train)}, Validation={len(X_valid)}")
        print(f"  >> 입력 데이터 형태 (첫 샘플): {X_train[0].shape}") # (TIME_STEPS, NUM_FEATURES_FOR_MODEL)

        # 6.4 모델 구축 및 컴파일
        model = build_lstm_model(input_shape=(TIME_STEPS, NUM_FEATURES_FOR_MODEL))
        model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss='mean_squared_error')

        # 6.5 모델 학습
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)
        model_checkpoint = ModelCheckpoint(model_save_file_path, monitor='val_loss', verbose=0, save_best_only=True)

        print(f"  >> 모델 학습 시작 (최대 {EPOCHS} 에포크)...")
        history = model.fit(
            X_train, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_valid, y_valid),
            callbacks=[early_stopping, model_checkpoint],
            verbose=0 # 학습 로그 최소화
        )

        # 6.6 학습 완료 및 결과 요약
        if 'val_loss' in history.history and history.history['val_loss']:
             best_epoch = np.argmin(history.history['val_loss']) + 1
             min_val_loss = np.min(history.history['val_loss'])
             print(f"  >> 모델 학습 완료. 최적 에포크: {best_epoch}, 최소 검증 손실(MSE): {min_val_loss:.6f}")
        else:
             print(f"  >> 모델 학습 완료 (기록 부족 또는 없음).") # EarlyStopping으로 1 epoch 전에 멈춘 경우 등
             min_val_loss = float('inf')


        if os.path.exists(model_save_file_path) and min_val_loss != float('inf'): # 저장되었고 유효한 학습이 이루어졌다면
             print(f"  >> 최적 모델 저장됨: {model_save_file_path}")
             models_trained_count += 1
        else:
             print(f"  >> 정보: 최적 모델 파일이 저장되지 않았거나 학습이 유효하지 않을 수 있습니다 (경로: {model_save_file_path}, 최소 val_loss: {min_val_loss}).")
             # 실패 카운트보다는, 학습은 시도했으므로 별도 처리 가능

        # 메모리 관리
        del df_loaded, feature_data, target_data, X, y, X_train, y_train, X_valid, y_valid, model, history
        tf.keras.backend.clear_session()
        gc.collect()

    except Exception as e:
        print(f"  >> 오류: 티커 {ticker} 처리 중 예외 발생: {e}")
        traceback.print_exc()
        models_failed_count += 1
        continue
    finally:
        ticker_train_end_time = time.time()
        print(f"  Ticker: {ticker} 학습 시간: {ticker_train_end_time - ticker_train_start_time:.2f} 초")

# --- 최종 결과 출력 ---
total_train_end_time = time.time()
print("\n--- 전체 종목 모델 재학습 완료 ---")
print(f"총 소요 시간: {(total_train_end_time - total_train_start_time) / 60:.2f} 분")
print(f"성공적으로 학습/저장된 모델 수: {models_trained_count}")
print(f"실패 또는 건너뛴 종목 수: {models_failed_count}")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.002427
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000640.keras
#   Ticker: 000640 학습 시간: 12.07 초
#
# [40/663] Ticker: 000650 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000926
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000650.keras
#   Ticker: 000650 학습 시간: 8.77 초
#
# [41/663] Ticker: 000660 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.026661
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000660.keras
#   Ticker: 000660 학습 시간: 9.19 초
#
# [42/663] Ticker: 000670 학습 시작...
#   >> 데이터 분할: Train=814, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.000426
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000670.keras
#   Ticker: 000670 학습 시간: 15.20 초
#
# [43/663] Ticker: 000680 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.007695
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000680.keras
#   Ticker: 000680 학습 시간: 10.90 초
#
# [44/663] Ticker: 000700 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 47, 최소 검증 손실(MSE): 0.000729
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000700.keras
#   Ticker: 000700 학습 시간: 24.99 초
#
# [45/663] Ticker: 000720 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.000600
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000720.keras
#   Ticker: 000720 학습 시간: 9.44 초
#
# [46/663] Ticker: 000725 학습 시작...
#   >> 데이터 분할: Train=820, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 31, 최소 검증 손실(MSE): 0.000014
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000725.keras
#   Ticker: 000725 학습 시간: 20.21 초
#
# [47/663] Ticker: 000760 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 27, 최소 검증 손실(MSE): 0.000110
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000760.keras
#   Ticker: 000760 학습 시간: 17.68 초
#
# [48/663] Ticker: 000810 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 20, 최소 검증 손실(MSE): 0.007624
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000810.keras
#   Ticker: 000810 학습 시간: 14.42 초
#
# [49/663] Ticker: 000815 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 26, 최소 검증 손실(MSE): 0.006573
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000815.keras
#   Ticker: 000815 학습 시간: 19.86 초
#
# [50/663] Ticker: 000850 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 6, 최소 검증 손실(MSE): 0.004201
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000850.keras
#   Ticker: 000850 학습 시간: 11.21 초
#
# [51/663] Ticker: 000860 학습 시작...
#   >> 데이터 분할: Train=814, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.002512
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000860.keras
#   Ticker: 000860 학습 시간: 13.45 초
#
# [52/663] Ticker: 000880 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 47, 최소 검증 손실(MSE): 0.000817
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000880.keras
#   Ticker: 000880 학습 시간: 23.25 초
#
# [53/663] Ticker: 000885 학습 시작...
#   >> 데이터 분할: Train=820, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.001089
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000885.keras
#   Ticker: 000885 학습 시간: 14.06 초
#
# [54/663] Ticker: 00088K 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000878
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/00088K.keras
#   Ticker: 00088K 학습 시간: 14.66 초
#
# [55/663] Ticker: 000890 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000121
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000890.keras
#   Ticker: 000890 학습 시간: 14.42 초
#
# [56/663] Ticker: 000910 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 38, 최소 검증 손실(MSE): 0.000569
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000910.keras
#   Ticker: 000910 학습 시간: 22.40 초
#
# [57/663] Ticker: 000950 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000105
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000950.keras
#   Ticker: 000950 학습 시간: 15.84 초
#
# [58/663] Ticker: 000970 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000386
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000970.keras
#   Ticker: 000970 학습 시간: 16.41 초
#
# [59/663] Ticker: 000990 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 49, 최소 검증 손실(MSE): 0.001245
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/000990.keras
#   Ticker: 000990 학습 시간: 23.82 초
#
# [60/663] Ticker: 001020 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000128
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001020.keras
#   Ticker: 001020 학습 시간: 13.69 초
#
# [61/663] Ticker: 001040 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.008861
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001040.keras
#   Ticker: 001040 학습 시간: 12.06 초
#
# [62/663] Ticker: 001045 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 37, 최소 검증 손실(MSE): 0.002911
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001045.keras
#   Ticker: 001045 학습 시간: 25.87 초
#
# [63/663] Ticker: 00104K 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 11, 최소 검증 손실(MSE): 0.008655
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/00104K.keras
#   Ticker: 00104K 학습 시간: 12.20 초
#
# [64/663] Ticker: 001060 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 16, 최소 검증 손실(MSE): 0.004026
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001060.keras
#   Ticker: 001060 학습 시간: 14.40 초
#
# [65/663] Ticker: 001065 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.000075
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001065.keras
#   Ticker: 001065 학습 시간: 11.18 초
#
# [66/663] Ticker: 001067 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000054
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001067.keras
#   Ticker: 001067 학습 시간: 14.23 초
#
# [67/663] Ticker: 001070 학습 시작...
#   >> 데이터 분할: Train=812, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000038
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001070.keras
#   Ticker: 001070 학습 시간: 9.90 초
#
# [68/663] Ticker: 001080 학습 시작...
#   >> 데이터 분할: Train=645, Validation=138
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.017637
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001080.keras
#   Ticker: 001080 학습 시간: 13.09 초
#
# [69/663] Ticker: 001120 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 30, 최소 검증 손실(MSE): 0.000642
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001120.keras
#   Ticker: 001120 학습 시간: 20.56 초
#
# [70/663] Ticker: 001130 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 45, 최소 검증 손실(MSE): 0.001013
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001130.keras
#   Ticker: 001130 학습 시간: 21.64 초
#
# [71/663] Ticker: 001140 학습 시작...
#   >> 데이터 분할: Train=611, Validation=131
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.001248
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001140.keras
#   Ticker: 001140 학습 시간: 11.57 초
#
# [72/663] Ticker: 001200 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.008292
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001200.keras
#   Ticker: 001200 학습 시간: 15.19 초
#
# [73/663] Ticker: 001210 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 24, 최소 검증 손실(MSE): 0.000113
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001210.keras
#   Ticker: 001210 학습 시간: 17.84 초
#
# [74/663] Ticker: 001230 학습 시작...
#   >> 데이터 분할: Train=812, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 33, 최소 검증 손실(MSE): 0.000385
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001230.keras
#   Ticker: 001230 학습 시간: 19.64 초
#
# [75/663] Ticker: 001250 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 37, 최소 검증 손실(MSE): 0.002843
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001250.keras
#   Ticker: 001250 학습 시간: 23.16 초
#
# [76/663] Ticker: 001260 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.001067
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001260.keras
#   Ticker: 001260 학습 시간: 12.30 초
#
# [77/663] Ticker: 001270 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.006731
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001270.keras
#   Ticker: 001270 학습 시간: 14.39 초
#
# [78/663] Ticker: 001275 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 28, 최소 검증 손실(MSE): 0.001633
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001275.keras
#   Ticker: 001275 학습 시간: 17.81 초
#
# [79/663] Ticker: 001290 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000344
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001290.keras
#   Ticker: 001290 학습 시간: 15.14 초
#
# [80/663] Ticker: 001340 학습 시작...
#   >> 데이터 분할: Train=690, Validation=148
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.014210
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001340.keras
#   Ticker: 001340 학습 시간: 16.04 초
#
# [81/663] Ticker: 001360 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.001620
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001360.keras
#   Ticker: 001360 학습 시간: 10.00 초
#
# [82/663] Ticker: 001380 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.002571
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001380.keras
#   Ticker: 001380 학습 시간: 15.04 초
#
# [83/663] Ticker: 001390 학습 시작...
#   >> 데이터 분할: Train=818, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 11, 최소 검증 손실(MSE): 0.000448
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001390.keras
#   Ticker: 001390 학습 시간: 13.12 초
#
# [84/663] Ticker: 001420 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.001131
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001420.keras
#   Ticker: 001420 학습 시간: 15.38 초
#
# [85/663] Ticker: 001430 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.000916
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001430.keras
#   Ticker: 001430 학습 시간: 17.96 초
#
# [86/663] Ticker: 001440 학습 시작...
#   >> 데이터 분할: Train=809, Validation=173
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000625
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001440.keras
#   Ticker: 001440 학습 시간: 16.83 초
#
# [87/663] Ticker: 001450 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.003432
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001450.keras
#   Ticker: 001450 학습 시간: 16.12 초
#
# [88/663] Ticker: 001460 학습 시작...
#   >> 데이터 분할: Train=817, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.003992
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001460.keras
#   Ticker: 001460 학습 시간: 13.98 초
#
# [89/663] Ticker: 001465 학습 시작...
#   >> 데이터 분할: Train=817, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.039438
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001465.keras
#   Ticker: 001465 학습 시간: 14.95 초
#
# [90/663] Ticker: 001470 학습 시작...
#   >> 데이터 분할: Train=799, Validation=171
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000962
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001470.keras
#   Ticker: 001470 학습 시간: 13.92 초
#
# [91/663] Ticker: 001500 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 18, 최소 검증 손실(MSE): 0.000310
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001500.keras
#   Ticker: 001500 학습 시간: 16.08 초
#
# [92/663] Ticker: 001510 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.000425
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001510.keras
#   Ticker: 001510 학습 시간: 12.84 초
#
# [93/663] Ticker: 001515 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000196
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001515.keras
#   Ticker: 001515 학습 시간: 14.83 초
#
# [94/663] Ticker: 001520 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000080
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001520.keras
#   Ticker: 001520 학습 시간: 16.37 초
#
# [95/663] Ticker: 001525 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.000157
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001525.keras
#   Ticker: 001525 학습 시간: 12.42 초
#
# [96/663] Ticker: 001527 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 33, 최소 검증 손실(MSE): 0.000259
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001527.keras
#   Ticker: 001527 학습 시간: 20.90 초
#
# [97/663] Ticker: 001530 학습 시작...
#   >> 데이터 분할: Train=808, Validation=173
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.000721
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001530.keras
#   Ticker: 001530 학습 시간: 12.56 초
#
# [98/663] Ticker: 001550 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 45, 최소 검증 손실(MSE): 0.000145
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001550.keras
#   Ticker: 001550 학습 시간: 23.56 초
#
# [99/663] Ticker: 001560 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 20, 최소 검증 손실(MSE): 0.000631
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001560.keras
#   Ticker: 001560 학습 시간: 16.36 초
#
# [100/663] Ticker: 001570 학습 시작...
#   >> 데이터 분할: Train=799, Validation=171
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.001818
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001570.keras
#   Ticker: 001570 학습 시간: 15.60 초
#
# [101/663] Ticker: 001620 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 24, 최소 검증 손실(MSE): 0.000223
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001620.keras
#   Ticker: 001620 학습 시간: 18.56 초
#
# [102/663] Ticker: 001630 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.000428
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001630.keras
#   Ticker: 001630 학습 시간: 11.39 초
#
# [103/663] Ticker: 001680 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 38, 최소 검증 손실(MSE): 0.004832
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001680.keras
#   Ticker: 001680 학습 시간: 22.61 초
#
# [104/663] Ticker: 001685 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 48, 최소 검증 손실(MSE): 0.010095
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001685.keras
#   Ticker: 001685 학습 시간: 25.33 초
#
# [105/663] Ticker: 001720 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 28, 최소 검증 손실(MSE): 0.007056
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001720.keras
#   Ticker: 001720 학습 시간: 19.99 초
#
# [106/663] Ticker: 001740 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 45, 최소 검증 손실(MSE): 0.004606
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001740.keras
#   Ticker: 001740 학습 시간: 22.91 초
#
# [107/663] Ticker: 001750 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 20, 최소 검증 손실(MSE): 0.002368
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001750.keras
#   Ticker: 001750 학습 시간: 17.87 초
#
# [108/663] Ticker: 001755 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.001770
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001755.keras
#   Ticker: 001755 학습 시간: 10.94 초
#
# [109/663] Ticker: 001770 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 8, 최소 검증 손실(MSE): 0.000365
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001770.keras
#   Ticker: 001770 학습 시간: 11.78 초
#
# [110/663] Ticker: 001780 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000957
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001780.keras
#   Ticker: 001780 학습 시간: 14.52 초
#
# [111/663] Ticker: 001790 학습 시작...
#   >> 데이터 분할: Train=819, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000788
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001790.keras
#   Ticker: 001790 학습 시간: 12.52 초
#
# [112/663] Ticker: 001795 학습 시작...
#   >> 데이터 분할: Train=819, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.000397
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001795.keras
#   Ticker: 001795 학습 시간: 15.34 초
#
# [113/663] Ticker: 001800 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 50, 최소 검증 손실(MSE): 0.001359
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001800.keras
#   Ticker: 001800 학습 시간: 27.18 초
#
# [114/663] Ticker: 001820 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.001569
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001820.keras
#   Ticker: 001820 학습 시간: 13.50 초
#
# [115/663] Ticker: 001940 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.004190
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/001940.keras
#   Ticker: 001940 학습 시간: 14.78 초
#
# [116/663] Ticker: 002020 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 34, 최소 검증 손실(MSE): 0.000172
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002020.keras
#   Ticker: 002020 학습 시간: 21.51 초
#
# [117/663] Ticker: 002025 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 42, 최소 검증 손실(MSE): 0.000254
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002025.keras
#   Ticker: 002025 학습 시간: 24.33 초
#
# [118/663] Ticker: 002030 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.005987
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002030.keras
#   Ticker: 002030 학습 시간: 17.57 초
#
# [119/663] Ticker: 002070 학습 시작...
#   >> 데이터 분할: Train=812, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000549
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002070.keras
#   Ticker: 002070 학습 시간: 16.62 초
#
# [120/663] Ticker: 002100 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000365
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002100.keras
#   Ticker: 002100 학습 시간: 17.27 초
#
# [121/663] Ticker: 002140 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 34, 최소 검증 손실(MSE): 0.000118
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002140.keras
#   Ticker: 002140 학습 시간: 23.11 초
#
# [122/663] Ticker: 002150 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 26, 최소 검증 손실(MSE): 0.000939
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002150.keras
#   Ticker: 002150 학습 시간: 19.34 초
#
# [123/663] Ticker: 002170 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 46, 최소 검증 손실(MSE): 0.000457
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002170.keras
#   Ticker: 002170 학습 시간: 23.31 초
#
# [124/663] Ticker: 002200 학습 시작...
#   >> 데이터 분할: Train=817, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.002476
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002200.keras
#   Ticker: 002200 학습 시간: 14.86 초
#
# [125/663] Ticker: 002210 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000159
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002210.keras
#   Ticker: 002210 학습 시간: 15.08 초
#
# [126/663] Ticker: 002220 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000150
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002220.keras
#   Ticker: 002220 학습 시간: 17.30 초
#
# [127/663] Ticker: 002240 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 28, 최소 검증 손실(MSE): 0.004686
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002240.keras
#   Ticker: 002240 학습 시간: 20.33 초
#
# [128/663] Ticker: 002310 학습 시작...
#   >> 데이터 분할: Train=814, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.001152
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002310.keras
#   Ticker: 002310 학습 시간: 15.40 초
#
# [129/663] Ticker: 002320 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 8, 최소 검증 손실(MSE): 0.001084
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002320.keras
#   Ticker: 002320 학습 시간: 12.93 초
#
# [130/663] Ticker: 002350 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.001715
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002350.keras
#   Ticker: 002350 학습 시간: 17.42 초
#
# [131/663] Ticker: 002355 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.002707
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002355.keras
#   Ticker: 002355 학습 시간: 14.89 초
#
# [132/663] Ticker: 002360 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.000396
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002360.keras
#   Ticker: 002360 학습 시간: 12.06 초
#
# [133/663] Ticker: 002380 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.001610
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002380.keras
#   Ticker: 002380 학습 시간: 13.46 초
#
# [134/663] Ticker: 002390 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 18, 최소 검증 손실(MSE): 0.000515
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002390.keras
#   Ticker: 002390 학습 시간: 16.65 초
#
# [135/663] Ticker: 002410 학습 시작...
#   >> 데이터 분할: Train=799, Validation=171
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000103
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002410.keras
#   Ticker: 002410 학습 시간: 13.03 초
#
# [136/663] Ticker: 002420 학습 시작...
#   >> 데이터 분할: Train=588, Validation=126
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.002591
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002420.keras
#   Ticker: 002420 학습 시간: 12.23 초
#
# [137/663] Ticker: 002450 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.001210
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002450.keras
#   Ticker: 002450 학습 시간: 14.72 초
#
# [138/663] Ticker: 002460 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.000155
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002460.keras
#   Ticker: 002460 학습 시간: 12.91 초
#
# [139/663] Ticker: 002600 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 20, 최소 검증 손실(MSE): 0.000608
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002600.keras
#   Ticker: 002600 학습 시간: 18.63 초
#
# [140/663] Ticker: 002620 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000244
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002620.keras
#   Ticker: 002620 학습 시간: 15.99 초
#
# [141/663] Ticker: 002630 학습 시작...
#   >> 데이터 분할: Train=820, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 4, 최소 검증 손실(MSE): 0.000168
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002630.keras
#   Ticker: 002630 학습 시간: 13.13 초
#
# [142/663] Ticker: 002690 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000112
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002690.keras
#   Ticker: 002690 학습 시간: 14.44 초
#
# [143/663] Ticker: 002700 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 4, 최소 검증 손실(MSE): 0.000425
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002700.keras
#   Ticker: 002700 학습 시간: 11.51 초
#
# [144/663] Ticker: 002710 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.003807
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002710.keras
#   Ticker: 002710 학습 시간: 13.81 초
#
# [145/663] Ticker: 002720 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.004467
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002720.keras
#   Ticker: 002720 학습 시간: 14.47 초
#
# [146/663] Ticker: 002760 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000300
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002760.keras
#   Ticker: 002760 학습 시간: 12.18 초
#
# [147/663] Ticker: 002780 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.000449
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002780.keras
#   Ticker: 002780 학습 시간: 11.28 초
#
# [148/663] Ticker: 002785 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000224
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002785.keras
#   Ticker: 002785 학습 시간: 15.06 초
#
# [149/663] Ticker: 002787 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 6, 최소 검증 손실(MSE): 0.000260
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002787.keras
#   Ticker: 002787 학습 시간: 12.13 초
#
# [150/663] Ticker: 002790 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000604
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002790.keras
#   Ticker: 002790 학습 시간: 14.13 초
#
# [151/663] Ticker: 002795 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.000239
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/002795.keras
#   Ticker: 002795 학습 시간: 18.83 초
#
# [152/663] Ticker: 00279K 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000414
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/00279K.keras
#   Ticker: 00279K 학습 시간: 12.75 초
#
# [153/663] Ticker: 010690 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000928
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010690.keras
#   Ticker: 010690 학습 시간: 16.65 초
#
# [154/663] Ticker: 010770 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000046
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010770.keras
#   Ticker: 010770 학습 시간: 16.44 초
#
# [155/663] Ticker: 010780 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000305
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010780.keras
#   Ticker: 010780 학습 시간: 19.81 초
#
# [156/663] Ticker: 010820 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 16, 최소 검증 손실(MSE): 0.000368
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010820.keras
#   Ticker: 010820 학습 시간: 16.00 초
#
# [157/663] Ticker: 010950 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000619
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010950.keras
#   Ticker: 010950 학습 시간: 17.89 초
#
# [158/663] Ticker: 010955 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000500
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010955.keras
#   Ticker: 010955 학습 시간: 11.46 초
#
# [159/663] Ticker: 010960 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000280
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/010960.keras
#   Ticker: 010960 학습 시간: 14.82 초
#
# [160/663] Ticker: 011000 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.000135
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011000.keras
#   Ticker: 011000 학습 시간: 12.51 초
#
# [161/663] Ticker: 011070 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 37, 최소 검증 손실(MSE): 0.000873
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011070.keras
#   Ticker: 011070 학습 시간: 22.05 초
#
# [162/663] Ticker: 011090 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.000071
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011090.keras
#   Ticker: 011090 학습 시간: 13.20 초
#
# [163/663] Ticker: 011150 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 34, 최소 검증 손실(MSE): 0.008036
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011150.keras
#   Ticker: 011150 학습 시간: 23.07 초
#
# [164/663] Ticker: 011155 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 4, 최소 검증 손실(MSE): 0.000888
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011155.keras
#   Ticker: 011155 학습 시간: 11.81 초
#
# [165/663] Ticker: 011170 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.000574
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011170.keras
#   Ticker: 011170 학습 시간: 12.61 초
#
# [166/663] Ticker: 011200 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 23, 최소 검증 손실(MSE): 0.000358
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011200.keras
#   Ticker: 011200 학습 시간: 18.68 초
#
# [167/663] Ticker: 011210 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.000622
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011210.keras
#   Ticker: 011210 학습 시간: 14.28 초
#
# [168/663] Ticker: 011230 학습 시작...
#   >> 데이터 분할: Train=820, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.000490
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011230.keras
#   Ticker: 011230 학습 시간: 14.15 초
#
# [169/663] Ticker: 011280 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.000573
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011280.keras
#   Ticker: 011280 학습 시간: 17.18 초
#
# [170/663] Ticker: 011300 학습 시작...
#   >> 데이터 분할: Train=623, Validation=133
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 16, 최소 검증 손실(MSE): 0.000763
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011300.keras
#   Ticker: 011300 학습 시간: 15.04 초
#
# [171/663] Ticker: 011330 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.002286
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011330.keras
#   Ticker: 011330 학습 시간: 15.71 초
#
# [172/663] Ticker: 011390 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 31, 최소 검증 손실(MSE): 0.000558
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011390.keras
#   Ticker: 011390 학습 시간: 21.18 초
#
# [173/663] Ticker: 011420 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 27, 최소 검증 손실(MSE): 0.004877
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011420.keras
#   Ticker: 011420 학습 시간: 20.48 초
#
# [174/663] Ticker: 011500 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 27, 최소 검증 손실(MSE): 0.001893
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011500.keras
#   Ticker: 011500 학습 시간: 19.40 초
#
# [175/663] Ticker: 011690 학습 시작...
#   >> 데이터 분할: Train=469, Validation=100
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000460
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011690.keras
#   Ticker: 011690 학습 시간: 13.65 초
#
# [176/663] Ticker: 011700 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.000385
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011700.keras
#   Ticker: 011700 학습 시간: 14.00 초
#
# [177/663] Ticker: 011760 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 24, 최소 검증 손실(MSE): 0.002308
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011760.keras
#   Ticker: 011760 학습 시간: 17.86 초
#
# [178/663] Ticker: 011780 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.000666
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011780.keras
#   Ticker: 011780 학습 시간: 15.24 초
#
# [179/663] Ticker: 011785 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000372
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011785.keras
#   Ticker: 011785 학습 시간: 16.99 초
#
# [180/663] Ticker: 011790 학습 시작...
#   >> 데이터 분할: Train=813, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.006316
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011790.keras
#   Ticker: 011790 학습 시간: 18.48 초
#
# [181/663] Ticker: 011810 학습 시작...
#   >> 데이터 분할: Train=812, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 24, 최소 검증 손실(MSE): 0.001574
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011810.keras
#   Ticker: 011810 학습 시간: 17.39 초
#
# [182/663] Ticker: 011930 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.000675
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/011930.keras
#   Ticker: 011930 학습 시간: 15.32 초
#
# [183/663] Ticker: 012030 학습 시작...
#   >> 데이터 분할: Train=820, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000734
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012030.keras
#   Ticker: 012030 학습 시간: 10.99 초
#
# [184/663] Ticker: 012160 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 23, 최소 검증 손실(MSE): 0.000184
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012160.keras
#   Ticker: 012160 학습 시간: 17.05 초
#
# [185/663] Ticker: 012170 학습 시작...
#   >> 데이터 분할: Train=664, Validation=142
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.001278
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012170.keras
#   Ticker: 012170 학습 시간: 10.80 초
#
# [186/663] Ticker: 012200 학습 시작...
#   >> 데이터 분할: Train=736, Validation=157
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.001916
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012200.keras
#   Ticker: 012200 학습 시간: 17.23 초
#
# [187/663] Ticker: 012205 학습 시작...
#   >> 데이터 분할: Train=736, Validation=157
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000575
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012205.keras
#   Ticker: 012205 학습 시간: 13.48 초
#
# [188/663] Ticker: 012280 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 30, 최소 검증 손실(MSE): 0.000084
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012280.keras
#   Ticker: 012280 학습 시간: 19.86 초
#
# [189/663] Ticker: 012320 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 46, 최소 검증 손실(MSE): 0.001314
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012320.keras
#   Ticker: 012320 학습 시간: 25.93 초
#
# [190/663] Ticker: 012330 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 36, 최소 검증 손실(MSE): 0.001303
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012330.keras
#   Ticker: 012330 학습 시간: 22.63 초
#
# [191/663] Ticker: 012450 학습 시작...
#   >> 데이터 분할: Train=808, Validation=173
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.000315
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012450.keras
#   Ticker: 012450 학습 시간: 15.88 초
#
# [192/663] Ticker: 012510 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.005559
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012510.keras
#   Ticker: 012510 학습 시간: 10.88 초
#
# [193/663] Ticker: 012600 학습 시작...
#   >> 데이터 분할: Train=103, Validation=22
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.003157
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012600.keras
#   Ticker: 012600 학습 시간: 10.67 초
#
# [194/663] Ticker: 012610 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.000177
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012610.keras
#   Ticker: 012610 학습 시간: 15.20 초
#
# [195/663] Ticker: 012630 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 10, 최소 검증 손실(MSE): 0.000957
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012630.keras
#   Ticker: 012630 학습 시간: 13.86 초
#
# [196/663] Ticker: 012690 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.002338
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012690.keras
#   Ticker: 012690 학습 시간: 15.62 초
#
# [197/663] Ticker: 012750 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 24, 최소 검증 손실(MSE): 0.000544
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012750.keras
#   Ticker: 012750 학습 시간: 18.69 초
#
# [198/663] Ticker: 012800 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 49, 최소 검증 손실(MSE): 0.001619
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/012800.keras
#   Ticker: 012800 학습 시간: 24.13 초
#
# [199/663] Ticker: 013000 학습 시작...
#   >> 데이터 분할: Train=732, Validation=156
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.000045
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/013000.keras
#   Ticker: 013000 학습 시간: 10.98 초
#
# [200/663] Ticker: 013360 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000114
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/013360.keras
#   Ticker: 013360 학습 시간: 17.22 초
#
# [201/663] Ticker: 013520 학습 시작...
#   >> 데이터 분할: Train=813, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.000433
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/013520.keras
#   Ticker: 013520 학습 시간: 18.19 초
#
# [202/663] Ticker: 013570 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
# ...
#   Ticker: 307950 학습 시간: 20.99 초
#
# [610/663] Ticker: 308170 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.000254
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/308170.keras
#   Ticker: 308170 학습 시간: 19.43 초
#
# [611/663] Ticker: 316140 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.002730
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/316140.keras
#   Ticker: 316140 학습 시간: 22.28 초
#
# [612/663] Ticker: 317400 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 11, 최소 검증 손실(MSE): 0.000252
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/317400.keras
#   Ticker: 317400 학습 시간: 23.25 초
#
# [613/663] Ticker: 322000 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 30, 최소 검증 손실(MSE): 0.000594
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/322000.keras
#   Ticker: 322000 학습 시간: 29.20 초
#
# [614/663] Ticker: 323410 학습 시작...
#   >> 데이터 분할: Train=543, Validation=116
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 18, 최소 검증 손실(MSE): 0.000700
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/323410.keras
#   Ticker: 323410 학습 시간: 24.07 초
#
# [615/663] Ticker: 326030 학습 시작...
#   >> 데이터 분할: Train=734, Validation=157
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.000957
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/326030.keras
#   Ticker: 326030 학습 시간: 20.69 초
#
# [616/663] Ticker: 329180 학습 시작...
#   >> 데이터 분할: Train=522, Validation=112
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 16, 최소 검증 손실(MSE): 0.004895
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/329180.keras
#   Ticker: 329180 학습 시간: 23.67 초
#
# [617/663] Ticker: 336260 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000708
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/336260.keras
#   Ticker: 336260 학습 시간: 23.26 초
#
# [618/663] Ticker: 33626K 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 16, 최소 검증 손실(MSE): 0.000201
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/33626K.keras
#   Ticker: 33626K 학습 시간: 24.95 초
#
# [619/663] Ticker: 33626L 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 23, 최소 검증 손실(MSE): 0.000456
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/33626L.keras
#   Ticker: 33626L 학습 시간: 26.47 초
#
# [620/663] Ticker: 336370 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 9, 최소 검증 손실(MSE): 0.001102
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/336370.keras
#   Ticker: 336370 학습 시간: 23.03 초
#
# [621/663] Ticker: 33637K 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 8, 최소 검증 손실(MSE): 0.000268
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/33637K.keras
#   Ticker: 33637K 학습 시간: 23.20 초
#
# [622/663] Ticker: 33637L 학습 시작...
#   >> 데이터 분할: Train=821, Validation=175
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.000765
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/33637L.keras
#   Ticker: 33637L 학습 시간: 20.38 초
#
# [623/663] Ticker: 339770 학습 시작...
#   >> 데이터 분할: Train=671, Validation=143
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 19, 최소 검증 손실(MSE): 0.000957
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/339770.keras
#   Ticker: 339770 학습 시간: 25.38 초
#
# [624/663] Ticker: 344820 학습 시작...
#   >> 데이터 분할: Train=812, Validation=174
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 22, 최소 검증 손실(MSE): 0.000141
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/344820.keras
#   Ticker: 344820 학습 시간: 26.47 초
#
# [625/663] Ticker: 352820 학습 시작...
#   >> 데이터 분할: Train=685, Validation=146
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 25, 최소 검증 손실(MSE): 0.000783
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/352820.keras
#   Ticker: 352820 학습 시간: 26.29 초
#
# [626/663] Ticker: 353200 학습 시작...
#   >> 데이터 분할: Train=755, Validation=161
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.001293
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/353200.keras
#   Ticker: 353200 학습 시간: 21.46 초
#
# [627/663] Ticker: 35320K 학습 시작...
#   >> 데이터 분할: Train=755, Validation=161
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 15, 최소 검증 손실(MSE): 0.000211
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/35320K.keras
#   Ticker: 35320K 학습 시간: 25.11 초
#
# [628/663] Ticker: 361610 학습 시작...
#   >> 데이터 분할: Train=586, Validation=125
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.001117
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/361610.keras
#   Ticker: 361610 학습 시간: 18.74 초
#
# [629/663] Ticker: 363280 학습 시작...
#   >> 데이터 분할: Train=693, Validation=148
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000045
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/363280.keras
#   Ticker: 363280 학습 시간: 20.73 초
#
# [630/663] Ticker: 36328K 학습 시작...
#   >> 데이터 분할: Train=693, Validation=148
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.000154
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/36328K.keras
#   Ticker: 36328K 학습 시간: 19.64 초
#
# [631/663] Ticker: 372910 학습 시작...
#   >> 데이터 분할: Train=539, Validation=115
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.004572
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/372910.keras
#   Ticker: 372910 학습 시간: 20.16 초
#
# [632/663] Ticker: 373220 학습 시작...
#   >> 데이터 분할: Train=461, Validation=98
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 3, 최소 검증 손실(MSE): 0.003205
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/373220.keras
#   Ticker: 373220 학습 시간: 19.27 초
#
# [633/663] Ticker: 375500 학습 시작...
#   >> 데이터 분할: Train=637, Validation=136
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 11, 최소 검증 손실(MSE): 0.001513
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/375500.keras
#   Ticker: 375500 학습 시간: 21.83 초
#
# [634/663] Ticker: 37550K 학습 시작...
#   >> 데이터 분할: Train=637, Validation=136
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 18, 최소 검증 손실(MSE): 0.000801
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/37550K.keras
#   Ticker: 37550K 학습 시간: 24.68 초
#
# [635/663] Ticker: 37550L 학습 시작...
#   >> 데이터 분할: Train=419, Validation=89
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 21, 최소 검증 손실(MSE): 0.004543
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/37550L.keras
#   Ticker: 37550L 학습 시간: 25.07 초
#
# [636/663] Ticker: 377300 학습 시작...
#   >> 데이터 분할: Train=503, Validation=107
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.000328
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/377300.keras
#   Ticker: 377300 학습 시간: 20.01 초
#
# [637/663] Ticker: 377740 학습 시작...
#   >> 데이터 분할: Train=305, Validation=65
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.003134
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/377740.keras
#   Ticker: 377740 학습 시간: 20.31 초
#
# [638/663] Ticker: 378850 학습 시작...
#   >> 데이터 분할: Train=614, Validation=131
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 40, 최소 검증 손실(MSE): 0.002632
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/378850.keras
#   Ticker: 378850 학습 시간: 31.88 초
#
# [639/663] Ticker: 381970 학습 시작...
#   >> 데이터 분할: Train=513, Validation=110
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 6, 최소 검증 손실(MSE): 0.000375
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/381970.keras
#   Ticker: 381970 학습 시간: 20.48 초
#
# [640/663] Ticker: 383220 학습 시작...
#   >> 데이터 분할: Train=579, Validation=124
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000675
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/383220.keras
#   Ticker: 383220 학습 시간: 24.02 초
#
# [641/663] Ticker: 383800 학습 시작...
#   >> 데이터 분할: Train=578, Validation=124
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 11, 최소 검증 손실(MSE): 0.000489
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/383800.keras
#   Ticker: 383800 학습 시간: 22.68 초
#
# [642/663] Ticker: 38380K 학습 시작...
#   >> 데이터 분할: Train=578, Validation=124
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.000135
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/38380K.keras
#   Ticker: 38380K 학습 시간: 23.58 초
#
# [643/663] Ticker: 402340 학습 시작...
#   >> 데이터 분할: Train=490, Validation=105
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.012050
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/402340.keras
#   Ticker: 402340 학습 시간: 20.35 초
#
# [644/663] Ticker: 403550 학습 시작...
#   >> 데이터 분할: Train=364, Validation=78
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 12, 최소 검증 손실(MSE): 0.001189
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/403550.keras
#   Ticker: 403550 학습 시간: 21.12 초
#
# [645/663] Ticker: 443060 학습 시작...
#   >> 데이터 분할: Train=70, Validation=15
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.004613
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/443060.keras
#   Ticker: 443060 학습 시간: 18.01 초
#
# [646/663] Ticker: 446070 학습 시작...
#   >> 데이터 분할: Train=318, Validation=68
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 6, 최소 검증 손실(MSE): 0.000605
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/446070.keras
#   Ticker: 446070 학습 시간: 19.94 초
#
# [647/663] Ticker: 450080 학습 시작...
#   >> 데이터 분할: Train=150, Validation=32
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.017256
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/450080.keras
#   Ticker: 450080 학습 시간: 18.32 초
#
# [648/663] Ticker: 450140 학습 시작...
#   >> 데이터 분할: Train=288, Validation=61
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 23, 최소 검증 손실(MSE): 0.016974
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/450140.keras
#   Ticker: 450140 학습 시간: 23.02 초
#
# [649/663] Ticker: 45014K 학습 시작...
#   >> 데이터 분할: Train=288, Validation=61
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.060190
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/45014K.keras
#   Ticker: 45014K 학습 시간: 19.25 초
#
# [650/663] Ticker: 452260 학습 시작...
#   >> 데이터 분할: Train=259, Validation=55
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.002259
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/452260.keras
#   Ticker: 452260 학습 시간: 17.95 초
#
# [651/663] Ticker: 45226K 학습 시작...
#   >> 데이터 분할: Train=259, Validation=55
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.002351
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/45226K.keras
#   Ticker: 45226K 학습 시간: 20.61 초
#
# [652/663] Ticker: 453340 학습 시작...
#   >> 데이터 분할: Train=254, Validation=54
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.090557
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/453340.keras
#   Ticker: 453340 학습 시간: 19.41 초
#
# [653/663] Ticker: 454910 학습 시작...
#   >> 데이터 분할: Train=171, Validation=36
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 5, 최소 검증 손실(MSE): 0.001927
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/454910.keras
#   Ticker: 454910 학습 시간: 20.08 초
#
# [654/663] Ticker: 456040 학습 시작...
#   >> 데이터 분할: Train=231, Validation=49
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 17, 최소 검증 손실(MSE): 0.002389
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/456040.keras
#   Ticker: 456040 학습 시간: 21.42 초
#
# [655/663] Ticker: 457190 학습 시작...
#   >> 데이터 분할: Train=226, Validation=48
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 49, 최소 검증 손실(MSE): 0.003503
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/457190.keras
#   Ticker: 457190 학습 시간: 26.45 초
#
# [656/663] Ticker: 460850 학습 시작...
#   >> 데이터 분할: Train=223, Validation=47
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 14, 최소 검증 손실(MSE): 0.005283
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/460850.keras
#   Ticker: 460850 학습 시간: 20.15 초
#
# [657/663] Ticker: 460860 학습 시작...
#   >> 데이터 분할: Train=223, Validation=47
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 13, 최소 검증 손실(MSE): 0.002659
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/460860.keras
#   Ticker: 460860 학습 시간: 21.69 초
#
# [658/663] Ticker: 462520 학습 시작...
#   >> 데이터 분할: Train=202, Validation=43
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 27, 최소 검증 손실(MSE): 0.000475
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/462520.keras
#   Ticker: 462520 학습 시간: 24.32 초
#
# [659/663] Ticker: 462870 학습 시작...
#   >> 데이터 분할: Train=39, Validation=8
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 27, 최소 검증 손실(MSE): 0.017756
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/462870.keras
#   Ticker: 462870 학습 시간: 20.91 초
#
# [660/663] Ticker: 465770 학습 시작...
#   >> 데이터 분할: Train=178, Validation=38
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 7, 최소 검증 손실(MSE): 0.003787
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/465770.keras
#   Ticker: 465770 학습 시간: 20.23 초
#
# [661/663] Ticker: 475150 학습 시작...
#   >> 데이터 분할: Train=88, Validation=18
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 4, 최소 검증 손실(MSE): 0.004233
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/475150.keras
#   Ticker: 475150 학습 시간: 18.88 초
#
# [662/663] Ticker: 475560 학습 시작...
#   >> 데이터 분할: Train=28, Validation=6
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 1, 최소 검증 손실(MSE): 0.003334
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/475560.keras
#   Ticker: 475560 학습 시간: 18.73 초
#
# [663/663] Ticker: 487570 학습 시작...
#   >> 데이터 분할: Train=31, Validation=6
#   >> 입력 데이터 형태 (첫 샘플): (20, 27)
#   >> 모델 학습 시작 (최대 50 에포크)...
#   >> 모델 학습 완료. 최적 에포크: 2, 최소 검증 손실(MSE): 0.006892
#   >> 최적 모델 저장됨: /content/drive/MyDrive/lstm_models_per_stock_v2/487570.keras
#   Ticker: 487570 학습 시간: 18.78 초
#
# --- 전체 종목 모델 재학습 완료 ---
# 총 소요 시간: 210.31 분
# 성공적으로 학습/저장된 모델 수: 663
# 실패 또는 건너뛴 종목 수: 0
